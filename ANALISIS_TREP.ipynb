# %% [markdown]
# <a href="https://colab.research.google.com/github/laresistance-bolivia/BOLIVIA_ELECCIONES_2019/blob/master/ANALISIS_TREP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis del TREP para las elecciones presidenciales 2019 de Bolivia

# %% [markdown]
# - De preferencia corre el notebook en Google Colab
#
# - La fuente de datos se descarga de manera automática de la siguiente fuente:
# https://drive.google.com/drive/folders/1z-Jwked3bX3ZiHEuy8ckvnSzRwAz62RF
#
# - La mayor parte de los gráficos son interactivos, puedes habilitar y deshabilitar opciones desde el menú lateral y hacer zoom sobre los mismos.

# %%
# Download DB
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1StCAGlX-ddYqFcdmtQWDUCuRRqKrfGgL' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1StCAGlX-ddYqFcdmtQWDUCuRRqKrfGgL" -O historico_actas.zip && rm -rf /tmp/cookies.txt

# %%
# !unzip historico_actas.zip
# Out:
# Archive:  historico_actas.zip
#   inflating: DatosActasPorHora.db

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import plotly.express as px
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
# DataBase connection
conn = sqlite3.connect("DatosActasPorHora.db")

# %%
# Table Description
query = "PRAGMA table_info(ActasPresidenteTrep);"
pd.read_sql_query(query, conn)
# Out:
#     cid                name     type  notnull dflt_value  pk
# 0     0                  Id  INTEGER        1       None   1
# 1     1    FechaHoraArchivo     TEXT        1       None   0
# 2     2                Pais     TEXT        0       None   0
# 3     3  NumeroDepartamento  INTEGER        1       None   0
# 4     4           Provincia     TEXT        0       None   0
# 5     5     NumeroMunicipio  INTEGER        1       None   0
# 6     6           Municipio     TEXT        0       None   0
# 7     7     Circunscripcion     TEXT        0       None   0
# 8     8           Localidad     TEXT        0       None   0
# 9     9             Recinto     TEXT        0       None   0
# 10   10          NumeroMesa  INTEGER        1       None   0
# 11   11          CodigoMesa     TEXT        0       None   0
# 12   12            Eleccion     TEXT        0       None   0
# 13   13           Inscritos  INTEGER        1       None   0
# 14   14                  CC  INTEGER        1       None   0
# 15   15                 FPV  INTEGER        1       None   0
# 16   16                 MTS  INTEGER        1       None   0
# 17   17                 UCS  INTEGER        1       None   0
# 18   18                 MAS  INTEGER        1       None   0
# 19   19                M21F  INTEGER        1       None   0
# 20   20                 PDC  INTEGER        1       None   0
# 21   21                 MNR  INTEGER        1       None   0
# 22   22              PanBol  INTEGER        1       None   0
# 23   23             Validos  INTEGER        1       None   0
# 24   24             Blancos  INTEGER        1       None   0
# 25   25               Nulos  INTEGER        1       None   0
# 26   26           Computada     TEXT        0       None   0
# 27   27        Departamento     TEXT        0       None   0

# %%
# Registros por archivo
query = """
SELECT FechaHoraArchivo, count(*) as total_registros
FROM ActasPresidenteTrep 
group by FechaHoraArchivo
"""
df_actas_qty = pd.read_sql_query(query, conn)
df_actas_qty['FechaHoraArchivo'] = pd.to_datetime(df_actas_qty['FechaHoraArchivo'])
df_actas_qty
# Out:
#       FechaHoraArchivo  total_registros
# 0  2019-10-20 19:40:57            28975
# 1  2019-10-21 19:14:53            32849
# 2  2019-10-21 20:17:53            32920
# 3  2019-10-21 21:20:53            33013
# 4  2019-10-21 22:23:53            33044
# ..                 ...              ...
# 80 2019-10-25 06:01:40            33044
# 81 2019-10-25 07:04:40            33044
# 82 2019-10-25 08:07:40            33044
# 83 2019-10-25 09:10:40            33044
# 84 2019-10-25 10:13:40            33044
#
# [85 rows x 2 columns]

# %%
# df_actas_qty.plot(x="FechaHoraArchivo", y="total_registros")

# %% [markdown]
# ## Cantidad de Registros en Actas

# %%
configure_plotly_browser_state()
data = go.Scatter(
           x=df_actas_qty['FechaHoraArchivo'],
           y=df_actas_qty['total_registros'])

layout = go.Layout(title='Cantidad de Registros en actas', 
                   xaxis=dict(title='Fecha'),
                   yaxis=dict(title='Cantidad'))

fig = go.Figure(data, layout=layout)
iplot(fig)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="1195343a-397c-494f-9071-68d00bedb0ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1195343a-397c-494f-9071-68d00bedb0ad")) {
#                     Plotly.newPlot(
#                         '1195343a-397c-494f-9071-68d00bedb0ad',
#                         [{"type": "scatter", "x": ["2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T20:17:53", "2019-10-21T21:20:53", "2019-10-21T22:23:53", "2019-10-21T23:26:53", "2019-10-22T00:29:53", "2019-10-22T01:32:53", "2019-10-22T02:35:53", "2019-10-22T03:38:53", "2019-10-22T04:41:53", "2019-10-22T05:44:53", "2019-10-22T06:47:53", "2019-10-22T07:50:53", "2019-10-22T08:53:53", "2019-10-22T09:56:53", "2019-10-22T10:59:53", "2019-10-22T12:02:53", "2019-10-22T13:05:53", "2019-10-22T14:05:53", "2019-10-22T15:08:53", "2019-10-22T16:11:53", "2019-10-22T17:14:53", "2019-10-22T18:17:53", "2019-10-22T19:20:53", "2019-10-22T20:23:53", "2019-10-22T21:26:53", "2019-10-22T22:29:53", "2019-10-22T23:32:53", "2019-10-23T00:35:53", "2019-10-23T01:38:53", "2019-10-23T02:41:53", "2019-10-23T03:43:40", "2019-10-23T04:46:40", "2019-10-23T05:49:40", "2019-10-23T06:52:40", "2019-10-23T07:55:40", "2019-10-23T08:58:40", "2019-10-23T10:01:40", "2019-10-23T11:04:40", "2019-10-23T12:07:40", "2019-10-23T13:10:40", "2019-10-23T14:13:40", "2019-10-23T15:16:40", "2019-10-23T16:19:40", "2019-10-23T17:22:40", "2019-10-23T18:25:40", "2019-10-23T19:28:40", "2019-10-23T20:31:40", "2019-10-23T21:34:40", "2019-10-23T22:37:40", "2019-10-23T23:40:40", "2019-10-24T00:43:40", "2019-10-24T01:46:40", "2019-10-24T02:49:40", "2019-10-24T03:52:40", "2019-10-24T04:55:40", "2019-10-24T05:58:40", "2019-10-24T07:01:40", "2019-10-24T08:04:40", "2019-10-24T09:07:40", "2019-10-24T10:10:40", "2019-10-24T11:13:40", "2019-10-24T12:16:40", "2019-10-24T13:19:40", "2019-10-24T14:22:40", "2019-10-24T15:16:40", "2019-10-24T16:19:40", "2019-10-24T17:22:40", "2019-10-24T18:25:40", "2019-10-24T19:28:40", "2019-10-24T20:31:40", "2019-10-24T21:34:40", "2019-10-24T22:37:40", "2019-10-24T23:40:40", "2019-10-25T00:43:40", "2019-10-25T01:46:40", "2019-10-25T02:52:40", "2019-10-25T03:55:40", "2019-10-25T04:58:40", "2019-10-25T06:01:40", "2019-10-25T07:04:40", "2019-10-25T08:07:40", "2019-10-25T09:10:40", "2019-10-25T10:13:40"], "y": [28975, 32849, 32920, 33013, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044, 33044]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scat ...

# %% [markdown]
# ##### Cálculos

# %%
cols_partidos = ['CC', 'FPV', 'MTS', 'UCS', 'MAS', 'M21F', 'PDC', 'MNR', 'PanBol']

# %%
# Obtener todas las actas
query = "SELECT * FROM ActasPresidenteTrep"
df_actas_all = pd.read_sql_query(query, conn)
df_actas_all['FechaHoraArchivo'] = pd.to_datetime(df_actas_all['FechaHoraArchivo'])
df_actas_all.sort_values( by=['FechaHoraArchivo'], inplace=True)

# %%
# Solo valores numéricos
# df_actas_all_numericos = df_actas_all[['CodigoMesa', 'FechaHoraArchivo' ] + cols_partidos + ['Validos', 'Blancos', 'Nulos', 'Inscritos']]
# df_actas_all_numericos.head()

# %%
# Cálculo de votos válidos
df_actas_all['_ValidosCalculado'] = df_actas_all[cols_partidos].sum(axis=1)
df_actas_all['_Validos_menos_ValidosCalculado'] = df_actas_all['Validos'] - df_actas_all['_ValidosCalculado']
df_actas_all['_Validos_menos_ValidosCalculado_Abs'] = df_actas_all['_Validos_menos_ValidosCalculado'].abs()

# Ausentismo
df_actas_all['_Ausentismo_OEP'] = df_actas_all['Inscritos'] - (df_actas_all['Validos'] + df_actas_all['Blancos'] + df_actas_all['Nulos'])
df_actas_all['_Ausentismo_Calculado'] = df_actas_all['Inscritos'] - (df_actas_all['_ValidosCalculado'] + df_actas_all['Blancos'] + df_actas_all['Nulos'])

# Total de Votantes por mesa
df_actas_all['_Votantes'] = df_actas_all['_ValidosCalculado'] + df_actas_all['Blancos'] + df_actas_all['Nulos']

# Asistencia Total en mesas
df_actas_all['_TotalAsistencia'] = 'NO'
df_actas_all.loc[df_actas_all['_Votantes'] == df_actas_all['Inscritos'] , '_TotalAsistencia'] = 'SI' 


# Mesa Ganadora
df_actas_all['_PartidoGanador'] = df_actas_all[cols_partidos].idxmax(axis=1)


df_actas_all.head()
# Out:
#           Id    FechaHoraArchivo  ... _TotalAsistencia  _PartidoGanador
# 0          1 2019-10-20 19:40:57  ...               NO               CC
# 19324  19325 2019-10-20 19:40:57  ...               NO              MAS
# 19323  19324 2019-10-20 19:40:57  ...               NO              MAS
# 19322  19323 2019-10-20 19:40:57  ...               NO              MAS
# 19321  19322 2019-10-20 19:40:57  ...               NO              MAS
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Ultimo archivo disponible

# %%
# Acta final (En base a la fecha máxima)
acta_final_fecha = str(df_actas_all['FechaHoraArchivo'].max())
acta_final_fecha
# Out:
# '2019-10-25 10:13:40'

# %%
# Cálculos sobre la última acta
print("Cálculos sobre la última acta")
# Errores de calculo de sumatoria votos validos  en la ultima acta 
df_validos_mal_computados = df_actas_all[(df_actas_all['FechaHoraArchivo'] == acta_final_fecha) & (df_actas_all['_Validos_menos_ValidosCalculado_Abs'] != 0)].groupby(by=['Departamento', 'Municipio'] ).sum()[['_Validos_menos_ValidosCalculado_Abs', '_Ausentismo_Calculado']].reset_index()

## Ausentismo ultima acta
df_ausentismo_calculado = df_actas_all[(df_actas_all['FechaHoraArchivo'] == acta_final_fecha) & (df_actas_all['_Ausentismo_Calculado'] != 0)].groupby(by=['Departamento', 'Municipio', '_PartidoGanador'] ).sum()[['_Ausentismo_Calculado']].reset_index()

## Resumen 
df_actas_inscritos = df_actas_all[(df_actas_all['FechaHoraArchivo'] == acta_final_fecha)].groupby(by=['Pais', 'Departamento', 'Provincia']).sum()[['Inscritos', '_ValidosCalculado', '_Ausentismo_Calculado', 'MAS', 'CC']].reset_index()
df_actas_inscritos.sample(5)
# Out:
# Cálculos sobre la última acta
#           Pais  Departamento  Provincia  ...  _Ausentismo_Calculado   MAS    CC
# 117    Bolivia         Pando   Manuripi  ...                   1202  3537  2141
# 13   Argentina  Buenos Aires    Pinamar  ...                    220   805    49
# 166      Chile         Arica      Arica  ...                    710  1614   382
# 108    Bolivia         Oruro     Sajama  ...                    851  2607   330
# 16   Argentina        Chubut  Escalante  ...                    480  1151    43
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Error de suma en votos válidos por municipio

# %%
configure_plotly_browser_state()
fig = px.bar(df_validos_mal_computados, x="Municipio", y="_Validos_menos_ValidosCalculado_Abs", title="Votos válidos mal sumados")
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="badf0e68-ab8e-4830-b4ec-15a564842260" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("badf0e68-ab8e-4830-b4ec-15a564842260")) {
#                     Plotly.newPlot(
#                         'badf0e68-ab8e-4830-b4ec-15a564842260',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Municipio=%{x}<br>_Validos_menos_ValidosCalculado_Abs=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Sevilla", "Baures", "Guayaramer\u00edn", "Huacaraje", "Loreto", "Puerto Menor de Rurrenabaque", "Reyes", "Riberalta", "San Andr\u00e9s", "San Borja", "San Ignacio", "San Javier", "San Joaqu\u00edn", "San Ram\u00f3n", "Santa Rosa", "Trinidad", "C.A. Buenos Aires", "General Pueyrred\u00f3n", "La Matanza", "Lomas de Zamora", "Pinamar", "Barcelona", "Comodoro Rivadavia", "Puerto Madryn", "Azurduy", "Camargo", "Culpina", "El Villar", "Huacareta", "Huacaya", "Macharet\u00ed", "Mojocoya", "Monteagudo", "Padilla", "Presto", "San Lucas", "Sopachui", "Sucre", "Tarabuco", "Tarvita", "Villa Abecia", "Villa Ricardo Mugia - Icla", "Villa Serrano", "Villa Vaca Guzm\u00e1n", "Yampar\u00e1ez", "Zuda\u00f1ez", "Anzaldo", "Arani", "Arbieto", "Ayopaya (Villa de Independencia)", "Capinota", "Chimor\u00e9", "Cliza", "Cocapata", "Cochabamba", "Colcapirhua", "Colomi", "Entre R\u00edos", "Mizque", "Morochata", "Pocona", "Pojo", "Puerto Villarroel", "Punata", "Quillacollo", "Raqaypampa", "Sacaba", "Sacabamba", "Santiva\u00f1ez", "Shinahota", "Sipesipe", "Tacopaya", "Tapacar\u00ed", "Tarata", "Tiquipaya", "Tiraque", "Tolata", "Totora", "Villa Rivero", "Villa Tunari", "Vinto", "Bilbao", "Perico", "San Salvador de Jujuy", "Achacachi", "Achocalla", "Apolo", "Ayo Ayo", "Batallas", "Cairoma", "Calacoto", "Calamarca", "Caquiaviri", "Caranavi", "Catacora", "Charazani", "Chulumani", "Chuma", "Collana", "Colquencha", "Colquiri", "Comanche", "Combaya", "Copacabana", "Coripata", "Corocoro", "Coroico", "El Alto", "Escoma", "Guanay", "Huarina", "Huatajata", "Humanata", "Inquisivi", "Irupana", "Ixiamas", "Jes\u00fas de Machaka", "La (Marka) San Andr\u00e9s de Machaca", "La Asunta", "Laja", "Luribay", "Mapiri", "Mocomoco", "Nuestra Se\u00f1ora de La Paz", "Palca", "Palos Blancos", "Papel Pampa", "Patacamaya", "Pelechuco", "Pucarani", "Puerto Acosta", "Puerto Mayor de Carabuco", "Puerto Mayor de Guaqui", "Puerto P\u00e9rez", "San Buenaventura", "San Pedro de Curahuara", "San Pedro de Tiquina", "Santiago de Callapa", "Santiago de Huata", "Sapahaqui", "Sicasica", "Sorata", "Taraco", "Teoponte", "Tiahuanacu", "Tipuani", "Umala", "Viacha", "Villa Ancoraimes", "Villa Libertad Licoma", "Yaco", "Yanacachi", "Madrid", "Capital", "Luj\u00e1n de Cuyo", "San Carlos", "Murcia", "Caracollo", "Challapata", "Choquecota", "Corque", "Oruro", "Paria (Soracachi)", "Poop\u00f3", "Sabaya", "Santuario de Quillacas", "Totora", "Bella Flor", "Bolpebra", "Cobija", "Filadelfia", "Ingavi", "Nueva Esperanza", "Porvenir", "Puerto Gonzalo Moreno", "San Lorenzo", "Santa Rosa", "Santos Mercado", "Sena", "Villa Nueva", "Atocha", "Betanzos", "Caripuyo", "Chaqu\u00ed", "Chayanta", "Ckochas", "Colquechaca", "Cotagaita", "Llallagua", "Llica", "Ocur\u00ed", "Pocoata", "Porco", "Potos\u00ed", "Puna (Villa Talavera)", "Ravelo", "Sacaca", "San Agust\u00edn", "San Pedro", "Tacobamba", "Tahua", "Tinguipaya", "Tomave", "Tupiza", "Unc\u00eda", "Uyuni", "Villaz\u00f3n", "Yocalla", "Camiri", "Concepci\u00f3n", "Cotoca", "Cuatro Ca\u00f1adas", "El Torno", "General Saavedra", "Guti\u00e9rrez", "La Guardia", "Lagunillas", "Montero", "Okinawa Uno", "Porongo", "Portachuelo", "Postrervalle", "Puerto Quijarro", "Puerto Suarez", "Quirusillas", "Robor\u00e9", "Samaipata", "San Carlos", "San Ignacio", "San Javier", "San Julian", "San Miguel", "San Ram\u00f3n", "Santa Cruz de La Sierra", "Santa Rosa", "Warnes", "Yapacan\u00ed", "G\u00fcer Aike", "Rosario", "Guarulhos", "Sao Paulo", "Bermejo", "Carapar\u00ed", "El Puente", "Entre R\u00edos", "Padcaya", "San Lorenzo", "Tarija", "Uriondo (Concepci\u00f3n)", "Villa Montes", "Yacuiba", "Yunchar\u00e1", "Valencia", "Arlington"], "xaxis": "x", "y": [79, 4, ...
#                         {"barmode": "relative", "height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histo

# %% [markdown]
# ## Mesas con asistencia total

# %%
## Mesas con total asistencia
# Corrigieron esto en la última version de las actas
df_total_asistencia = df_actas_all[(df_actas_all['FechaHoraArchivo'] == acta_final_fecha) & (df_actas_all['_TotalAsistencia'] == 'SI')].groupby(by=['Departamento', 'Provincia', 'Municipio', '_PartidoGanador'] ).sum()[['Inscritos', 'MAS', 'CC']].reset_index()

# df_total_asistencia = df_actas_all[df_actas_all['_TotalAsistencia'] == 'SI'].groupby(by=['FechaHoraArchivo', 'Departamento', 'Provincia', '_PartidoGanador'] ).sum()[['Inscritos', 'MAS', 'CC']].reset_index()
print(len(df_total_asistencia))
print("Muestra de 10 mesas")
df_total_asistencia.sample(10)
# Out:
# 129
# Muestra de 10 mesas
#    Departamento                  Provincia  ...  MAS   CC
# 71        Pando             Nicolas Suarez  ...   30    5
# 8    Chuquisaca             Hernando Siles  ...    1   14
# 66        Oruro                     Sabaya  ...   85  394
# 68        Pando                   Manuripi  ...   17   14
# 38       La Paz  General José Manuel Pando  ...   46    0
# 40       La Paz       Gualberto Villarroel  ...  213    1
# 17   Cochabamba                   Carrasco  ...  169    1
# 64        Oruro           Ladislao Cabrera  ...   45    5
# 7    Chuquisaca                    Azurduy  ...   21    0
# 49       La Paz                    Murillo  ...   80  103
#
# [10 rows x 7 columns]

# %% [markdown]
# ### Mesas con asistencia total por municipios y partido ganador

# %%
configure_plotly_browser_state()
fig = px.bar(df_total_asistencia, x="Municipio", y="Inscritos", title="_Asistencia Total en Mesas", color="_PartidoGanador")
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="4044853e-cc57-4451-899c-b6a2f904db52" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4044853e-cc57-4451-899c-b6a2f904db52")) {
#                     Plotly.newPlot(
#                         '4044853e-cc57-4451-899c-b6a2f904db52',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "_PartidoGanador=MAS<br>Municipio=%{x}<br>Inscritos=%{y}", "legendgroup": "_PartidoGanador=MAS", "marker": {"color": "#636efa"}, "name": "_PartidoGanador=MAS", "offsetgroup": "_PartidoGanador=MAS", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Trinidad", "Puerto Menor de Rurrenabaque", "Reyes", "San Andr\u00e9s", "Guayaramer\u00edn", "Berazategui", "La Matanza", "Azurduy", "Monteagudo", "Incahuasi", "Sopachui", "Ayopaya (Villa de Independencia)", "Cocapata", "Chimor\u00e9", "Pocona", "Pojo", "Puerto Villarroel", "Cochabamba", "Colomi", "Sacaba", "Villa Tunari", "Sacabamba", "Cliza", "Alalay", "Quillacollo", "Tiquipaya", "Tapacar\u00ed", "Tiraque", "Calamarca", "Patacamaya", "Sicasica", "Umala", "Mocomoco", "Caranavi", "Santiago de Machaca", "Papel Pampa", "San Pedro de Curahuara", "Viacha", "Colquiri", "Ichoca", "Sapahaqui", "Laja", "Pucarani", "Achocalla", "El Alto", "Mecapaca", "Chuma", "Achacachi", "Villa Ancoraimes", "Calacoto", "Waldo Ballivian", "Challapata", "Caracollo", "Oruro", "Paria (Soracachi)", "Salinas de Garc\u00ed Mendoza", "Puerto Gonzalo Moreno", "Filadelfia", "Porvenir", "Sacaca", "Tomave", "San Pedro", "Toro Toro", "Colquechaca", "Pocoata", "Ravelo", "Betanzos", "Villaz\u00f3n", "Cotagaita", "San Pedro de Quemes", "Atocha", "Tupiza", "Tinguipaya", "Cotoca", "El Torno", "La Guardia", "Santa Cruz de La Sierra", "Pail\u00f3n", "San Jos\u00e9", "Charagua", "Guti\u00e9rrez", "Lagunillas", "Pampa Grande", "Puerto Quijarro", "Buena Vista", "Yapacan\u00ed", "Saipina", "General Saavedra", "Vallegrande", "San Ignacio", "San Miguel", "Warnes", "Concepci\u00f3n", "San Javier", "San Julian", "Sao Jos\u00e9 do Rio Preto", "Sao Paulo", "Bermejo", "Uriondo (Concepci\u00f3n)", "Yacuiba"], "xaxis": "x", "y": [31, 469, 32, 44, 40, 236, 238, 23, 56, 20, 32, 109, 20, 530, 20, 196, 328, 92, 176, 371, 623, 55, 223, 38, 34, 284, 64, 24, 143, 109, 76, 21, 54, 252, 57, 63, 223, 141, 298, 114, 73, 298, 471, 83, 3022, 52, 28, 21, 172, 53, 24, 447, 43, 233, 36, 54, 48, 37, 47, 1415, 50, 47, 163, 122, 46, 23, 24, 75, 148, 18, 58, 275, 313, 230, 173, 601, 2644, 310, 13, 601, 380, 27, 449, 22, 128, 31, 80, 55, 32, 401, 18, 544, 219, 24, 46, 25, 502, 21, 27, 269], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "_PartidoGanador=CC<br>Municipio=%{x}<br>Inscritos=%{y}", "legendgroup": "_PartidoGanador=CC", "marker": {"color": "#EF553B"}, "name": "_PartidoGanador=CC", "offsetgroup": "_PartidoGanador=CC", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Monteagudo", "Sucre", "Cochabamba", "Tiquipaya", "El Alto", "Nuestra Se\u00f1ora de La Paz", "Madrid", "Oruro", "Cruz de Machacamarca", "Sabaya", "Puerto Rico", "Cobija", "Potos\u00ed", "Yocalla", "Cotoca", "La Guardia", "Santa Cruz de La Sierra", "Pail\u00f3n", "San Jos\u00e9", "Guti\u00e9rrez", "Puerto Quijarro", "Puerto Suarez", "San Carlos", "Montero", "Portachuelo", "Warnes"], "xaxis": "x", "y": [18, 133, 232, 44, 225, 1170, 238, 216, 89, 625, 51, 343, 70, 54, 230, 38, 6389, 113, 222, 16, 221, 269, 42, 678, 227, 326], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "_PartidoGanador=MTS<br>Municipio=%{x}<br>Inscritos=%{y}", "legendgroup": "_PartidoGanador=MTS", "marker": {"color": "#00cc96"}, "name": "_PartidoGanador=MTS", "offsetgroup": "_PartidoGanador=MTS", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sorata"], "xaxis": "x", "y": [31], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "_PartidoGanador=PDC<br>Municipio=%{x}<br>Inscritos=%{y}", "legendgroup": "_PartidoGanador=PDC", "marker": {"color": "#ab63fa"}, "name": "_PartidoGanador=PDC", "offsetgroup": "_PartidoGanador=PDC", "orientation": "v", "showlegend": true, "textposition": "auto", "t ...
#                         {"barmode": "relative", "height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidt

# %% [markdown]
# ## Inscritos por Departamento

# %%
configure_plotly_browser_state()
fig = px.bar(df_actas_inscritos, x="Departamento", y="Inscritos",  title="Inscritos", color= "Pais")
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="2ad84b3e-baee-4ddc-936b-998e66490a4b" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2ad84b3e-baee-4ddc-936b-998e66490a4b")) {
#                     Plotly.newPlot(
#                         '2ad84b3e-baee-4ddc-936b-998e66490a4b',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Alemania<br>Departamento=%{x}<br>Inscritos=%{y}", "legendgroup": "Pais=Alemania", "marker": {"color": "#636efa"}, "name": "Pais=Alemania", "offsetgroup": "Pais=Alemania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Berl\u00edn"], "xaxis": "x", "y": [287], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Argentina<br>Departamento=%{x}<br>Inscritos=%{y}", "legendgroup": "Pais=Argentina", "marker": {"color": "#EF553B"}, "name": "Pais=Argentina", "offsetgroup": "Pais=Argentina", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Chubut", "Chubut", "Cordoba", "Cordoba", "Cordoba", "Cordoba", "Corrientes", "Jujuy", "Jujuy", "Jujuy", "Jujuy", "La Pampa", "La Rioja", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Rio Negro", "Salta", "Salta", "San Juan", "San Luis", "Santa Cruz - Argentina", "Santa Cruz - Argentina", "Santa Fe", "Tucum\u00e1n"], "xaxis": "x", "y": [2375, 56754, 316, 2280, 6169, 728, 2066, 386, 27275, 7369, 6942, 3355, 1226, 2916, 1270, 1796, 3697, 414, 296, 152, 468, 7832, 400, 280, 533, 125, 496, 3884, 2531, 3401, 1375, 557, 1095, 2590, 464, 605, 384, 234, 864, 1185, 433], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Austria<br>Departamento=%{x}<br>Inscritos=%{y}", "legendgroup": "Pais=Austria", "marker": {"color": "#00cc96"}, "name": "Pais=Austria", "offsetgroup": "Pais=Austria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Viena"], "xaxis": "x", "y": [100], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Belgica<br>Departamento=%{x}<br>Inscritos=%{y}", "legendgroup": "Pais=Belgica", "marker": {"color": "#ab63fa"}, "name": "Pais=Belgica", "offsetgroup": "Pais=Belgica", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bruselas"], "xaxis": "x", "y": [234], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Bolivia<br>Departamento=%{x}<br>Inscritos=%{y}", "legendgroup": "Pais=Bolivia", "marker": {"color": "#FFA15A"}, "name": "Pais=Bolivia", "offsetgroup": "Pais=Bolivia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Pando", "Pando", "Pando", "Pando", "Pando", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Tarija", "Tarija", "Tarija", "Tarija", " ...

# %% [markdown]
# ## Ausentismo por departamento

# %%
configure_plotly_browser_state()
fig = px.bar(df_actas_inscritos, x="Departamento", y="_Ausentismo_Calculado",  title="Ausentismo", color= "Pais")
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="62d05d10-329a-4654-806c-81fcdd24487b" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("62d05d10-329a-4654-806c-81fcdd24487b")) {
#                     Plotly.newPlot(
#                         '62d05d10-329a-4654-806c-81fcdd24487b',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Alemania<br>Departamento=%{x}<br>_Ausentismo_Calculado=%{y}", "legendgroup": "Pais=Alemania", "marker": {"color": "#636efa"}, "name": "Pais=Alemania", "offsetgroup": "Pais=Alemania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Berl\u00edn"], "xaxis": "x", "y": [73], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Argentina<br>Departamento=%{x}<br>_Ausentismo_Calculado=%{y}", "legendgroup": "Pais=Argentina", "marker": {"color": "#EF553B"}, "name": "Pais=Argentina", "offsetgroup": "Pais=Argentina", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Chubut", "Chubut", "Cordoba", "Cordoba", "Cordoba", "Cordoba", "Corrientes", "Jujuy", "Jujuy", "Jujuy", "Jujuy", "La Pampa", "La Rioja", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Rio Negro", "Salta", "Salta", "San Juan", "San Luis", "Santa Cruz - Argentina", "Santa Cruz - Argentina", "Santa Fe", "Tucum\u00e1n"], "xaxis": "x", "y": [994, 22809, 65, 821, 2296, 162, 821, 65, 9415, 3426, 2478, 1285, 220, 1244, 163, 480, 1248, 140, 44, 11, 68, 3621, 64, 41, 142, 25, 140, 1616, 645, 1166, 316, 206, 471, 1069, 152, 132, 82, 20, 137, 479, 90], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Austria<br>Departamento=%{x}<br>_Ausentismo_Calculado=%{y}", "legendgroup": "Pais=Austria", "marker": {"color": "#00cc96"}, "name": "Pais=Austria", "offsetgroup": "Pais=Austria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Viena"], "xaxis": "x", "y": [33], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Belgica<br>Departamento=%{x}<br>_Ausentismo_Calculado=%{y}", "legendgroup": "Pais=Belgica", "marker": {"color": "#ab63fa"}, "name": "Pais=Belgica", "offsetgroup": "Pais=Belgica", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bruselas"], "xaxis": "x", "y": [62], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Bolivia<br>Departamento=%{x}<br>_Ausentismo_Calculado=%{y}", "legendgroup": "Pais=Bolivia", "marker": {"color": "#FFA15A"}, "name": "Pais=Bolivia", "offsetgroup": "Pais=Bolivia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Pando", "Pando", "Pando", "Pando", "Pando", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Tarij ...

# %% [markdown]
# ## Ausentismo por municipio y partido ganador

# %%
configure_plotly_browser_state()
fig = px.bar(df_ausentismo_calculado, x="Municipio", y="_Ausentismo_Calculado", title="Ausentismo", color='_PartidoGanador')
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="e83ddaa3-7423-492a-9b50-f524a241e8f5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e83ddaa3-7423-492a-9b50-f524a241e8f5")) {
#                     Plotly.newPlot(
#                         'e83ddaa3-7423-492a-9b50-f524a241e8f5',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "_PartidoGanador=CC<br>Municipio=%{x}<br>_Ausentismo_Calculado=%{y}", "legendgroup": "_PartidoGanador=CC", "marker": {"color": "#636efa"}, "name": "_PartidoGanador=CC", "offsetgroup": "_PartidoGanador=CC", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Epitaciol\u00e2ndia", "M\u00e1laga", "Sevilla", "Antofagasta", "Calama", "Beijing", "Guayaramer\u00edn", "Puerto Menor de Rurrenabaque", "Reyes", "Riberalta", "San Andr\u00e9s", "San Borja", "San Ignacio", "Santa Ana", "Santa Rosa", "Trinidad", "Berl\u00edn", "Bruselas", "C.A. Buenos Aires", "La Matanza", "Los Angeles", "Barcelona", "Camargo", "Huacareta", "Macharet\u00ed", "Monteagudo", "Padilla", "Sucre", "Tarabuco", "Villa Vaca Guzm\u00e1n", "Yotala", "Cochabamba", "Colcapirhua", "Punata", "Quillacollo", "Sacaba", "Tiquipaya", "Villa Tunari", "Vinto", "Cusco", "Asunci\u00f3n", "Washington D.C.", "Mosc\u00fa", "Estocolmo", "Bilbao", "Miami-Dade", "Ginebra", "La Haya", "Par\u00eds", "Londres", "Palma de Mallorca", "Tokio", "Achacachi", "Apolo", "Caranavi", "Chara\u00f1a", "Chulumani", "Chuma", "Coripata", "Coroico", "Desaguadero", "El Alto", "Irupana", "Ixiamas", "La Asunta", "Nuestra Se\u00f1ora de La Paz", "Quime", "San Buenaventura", "Viacha", "Roma", "Lima", "B\u00e9rgamo", "Mil\u00e1n", "Corumb\u00e1", "Madrid", "Managua", "Montgomery", "Santiago", "Montevideo", "Murcia", "M\u00e9xico D.F.", "Passaic", "New York", "Ottawa", "Carangas", "Coipasa", "Corque", "Cruz de Machacamarca", "Escara", "Esmeralda", "Huanuni", "Oruro", "Sabaya", "Todos Santos", "Yunguyo del Litoral", "Panam\u00e1", "Bella Flor", "Bolpebra", "Cobija", "Filadelfia", "Ingavi", "Nueva Esperanza", "Puerto Gonzalo Moreno", "Puerto Rico", "San Lorenzo", "San Pedro", "Santa Rosa", "Santos Mercado", "Sena", "Villa Nueva", "Quito", "Llallagua", "Porco", "Potos\u00ed", "Puna (Villa Talavera)", "San Pedro de Quemes", "Tupiza", "Unc\u00eda", "Uyuni", "Villaz\u00f3n", "Yocalla", "Providence", "R\u00edo de Janeiro", "San Jos\u00e9 - San Jos\u00e9", "Ascenci\u00f3n de Guarayos", "Boyuibe", "Buena Vista", "Cabezas", "Camiri", "Charagua", "Colpa B\u00e9lgica", "Comarapa", "Concepci\u00f3n", "Cotoca", "Cuatro Ca\u00f1adas", "Cuevo", "El Carmen Rivero T\u00f3rrez", "El Puente", "El Torno", "General Saavedra", "Guti\u00e9rrez", "La Guardia", "Lagunillas", "Mairana", "Mineros", "Montero", "Moromoro", "Okinawa Uno", "Pail\u00f3n", "Pampa Grande", "Porongo", "Portachuelo", "Postrervalle", "Puerto Quijarro", "Puerto Suarez", "Quirusillas", "Robor\u00e9", "Samaipata", "San Antonio de Lomerio", "San Carlos", "San Ignacio", "San Javier", "San Jos\u00e9", "San Juan", "San Julian", "San Mat\u00edas", "San Miguel", "San Rafael", "San Ram\u00f3n", "Santa Cruz de La Sierra", "Santa Rosa", "Trigal", "Urubicha", "Vallegrande", "Warnes", "Se\u00fal", "Iquique", "Bermejo", "Carapar\u00ed", "El Puente", "Entre R\u00edos", "Padcaya", "San Lorenzo", "Tarija", "Uriondo (Concepci\u00f3n)", "Villa Montes", "Yacuiba", "Valencia", "Viena", "Arlington", "Fairfax"], "xaxis": "x", "y": [9, 114, 2382, 1618, 404, 24, 3433, 569, 577, 5569, 18, 1095, 63, 1140, 694, 6429, 73, 62, 108, 239, 285, 11138, 163, 223, 210, 965, 7, 20894, 2, 427, 63, 33129, 2291, 24, 4429, 5313, 1479, 15, 288, 28, 136, 81, 78, 216, 3221, 475, 392, 42, 221, 600, 1000, 171, 209, 318, 25, 61, 982, 226, 536, 125, 15, 4350, 518, 114, 631, 39048, 2, 28, 24, 343, 187, 945, 742, 81, 10610, 5, 851, 1477, 57, 3113, 104, 306, 603, 62, 20, 39, 1, 47, 33, 37, 22, 10794, 299, 33, 27, 42, 73, 198, 4110, 60, 81, 83, 45, 69, 107, 57, 33, 192, 167, 67, 91, 220, 517, 12433, 166, 6, 757, 133, 620, 60, 136, 214, 132, 56, 575, 100, 295, 58, 2956, 235, 471, 24, 266, 2543, 80, 112, 183, 52, 267, 295, 120, 3570, 55, 53, 781, 4714, 82, 605, 1016, 149, 815, 1211, 93, 1001, 1609, 88, 1410, 445, 139, 428, 2773, 569, 1415, 143, 61, 121, 207, 383, 166, 90720, 531, 42, 52, ...

# %% [markdown]
# ## Votos válidos por departamento

# %%
configure_plotly_browser_state()
fig = px.bar(df_actas_inscritos, x="Departamento", y="_ValidosCalculado",  title="Votos Válidos", color= "Pais")
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="3b1a981c-6a0a-461d-aebd-7aac6a373a1c" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3b1a981c-6a0a-461d-aebd-7aac6a373a1c")) {
#                     Plotly.newPlot(
#                         '3b1a981c-6a0a-461d-aebd-7aac6a373a1c',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Alemania<br>Departamento=%{x}<br>_ValidosCalculado=%{y}", "legendgroup": "Pais=Alemania", "marker": {"color": "#636efa"}, "name": "Pais=Alemania", "offsetgroup": "Pais=Alemania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Berl\u00edn"], "xaxis": "x", "y": [213], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Argentina<br>Departamento=%{x}<br>_ValidosCalculado=%{y}", "legendgroup": "Pais=Argentina", "marker": {"color": "#EF553B"}, "name": "Pais=Argentina", "offsetgroup": "Pais=Argentina", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Chubut", "Chubut", "Cordoba", "Cordoba", "Cordoba", "Cordoba", "Corrientes", "Jujuy", "Jujuy", "Jujuy", "Jujuy", "La Pampa", "La Rioja", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Rio Negro", "Salta", "Salta", "San Juan", "San Luis", "Santa Cruz - Argentina", "Santa Cruz - Argentina", "Santa Fe", "Tucum\u00e1n"], "xaxis": "x", "y": [1213, 32980, 217, 1399, 3759, 519, 1216, 305, 17211, 3779, 4358, 2002, 954, 1615, 1022, 1243, 2340, 267, 233, 139, 386, 3986, 299, 226, 365, 97, 347, 2166, 1819, 2102, 1009, 333, 611, 1413, 272, 432, 292, 201, 702, 673, 329], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Austria<br>Departamento=%{x}<br>_ValidosCalculado=%{y}", "legendgroup": "Pais=Austria", "marker": {"color": "#00cc96"}, "name": "Pais=Austria", "offsetgroup": "Pais=Austria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Viena"], "xaxis": "x", "y": [66], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Belgica<br>Departamento=%{x}<br>_ValidosCalculado=%{y}", "legendgroup": "Pais=Belgica", "marker": {"color": "#ab63fa"}, "name": "Pais=Belgica", "offsetgroup": "Pais=Belgica", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bruselas"], "xaxis": "x", "y": [165], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Bolivia<br>Departamento=%{x}<br>_ValidosCalculado=%{y}", "legendgroup": "Pais=Bolivia", "marker": {"color": "#FFA15A"}, "name": "Pais=Bolivia", "offsetgroup": "Pais=Bolivia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Pando", "Pando", "Pando", "Pando", "Pando", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Tarij ...

# %% [markdown]
# ## Votos válidos a favor del MAS

# %%
configure_plotly_browser_state()
fig = px.bar(df_actas_inscritos, x="Departamento", y="MAS",  title="Votos Válidos a favor del MAS", color= "Pais")
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="f724fd76-dc6d-4a79-b277-f4c6296294df" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f724fd76-dc6d-4a79-b277-f4c6296294df")) {
#                     Plotly.newPlot(
#                         'f724fd76-dc6d-4a79-b277-f4c6296294df',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Alemania<br>Departamento=%{x}<br>MAS=%{y}", "legendgroup": "Pais=Alemania", "marker": {"color": "#636efa"}, "name": "Pais=Alemania", "offsetgroup": "Pais=Alemania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Berl\u00edn"], "xaxis": "x", "y": [42], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Argentina<br>Departamento=%{x}<br>MAS=%{y}", "legendgroup": "Pais=Argentina", "marker": {"color": "#EF553B"}, "name": "Pais=Argentina", "offsetgroup": "Pais=Argentina", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Chubut", "Chubut", "Cordoba", "Cordoba", "Cordoba", "Cordoba", "Corrientes", "Jujuy", "Jujuy", "Jujuy", "Jujuy", "La Pampa", "La Rioja", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Rio Negro", "Salta", "Salta", "San Juan", "San Luis", "Santa Cruz - Argentina", "Santa Cruz - Argentina", "Santa Fe", "Tucum\u00e1n"], "xaxis": "x", "y": [1085, 25060, 193, 1201, 3171, 440, 976, 266, 14698, 3283, 3766, 1697, 805, 1448, 781, 1151, 1762, 227, 187, 132, 318, 3583, 278, 202, 305, 77, 291, 1797, 1598, 1886, 903, 301, 571, 1103, 202, 357, 256, 180, 648, 582, 268], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Austria<br>Departamento=%{x}<br>MAS=%{y}", "legendgroup": "Pais=Austria", "marker": {"color": "#00cc96"}, "name": "Pais=Austria", "offsetgroup": "Pais=Austria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Viena"], "xaxis": "x", "y": [20], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Belgica<br>Departamento=%{x}<br>MAS=%{y}", "legendgroup": "Pais=Belgica", "marker": {"color": "#ab63fa"}, "name": "Pais=Belgica", "offsetgroup": "Pais=Belgica", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bruselas"], "xaxis": "x", "y": [33], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Bolivia<br>Departamento=%{x}<br>MAS=%{y}", "legendgroup": "Pais=Bolivia", "marker": {"color": "#FFA15A"}, "name": "Pais=Bolivia", "offsetgroup": "Pais=Bolivia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Pando", "Pando", "Pando", "Pando", "Pando", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Tarija", "Tarija", "Tarija", "Tarija", "Tarija", "Tarija"], "xaxis": "x", "y": [ ...

# %% [markdown]
# ## Votos válidos a favor de CC

# %%
configure_plotly_browser_state()
fig = px.bar(df_actas_inscritos, x="Departamento", y="CC",  title="Votos Válidos a favor de CC", color= "Pais")
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="ee92f401-4d5c-4244-a130-f62a3acef345" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ee92f401-4d5c-4244-a130-f62a3acef345")) {
#                     Plotly.newPlot(
#                         'ee92f401-4d5c-4244-a130-f62a3acef345',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Alemania<br>Departamento=%{x}<br>CC=%{y}", "legendgroup": "Pais=Alemania", "marker": {"color": "#636efa"}, "name": "Pais=Alemania", "offsetgroup": "Pais=Alemania", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Berl\u00edn"], "xaxis": "x", "y": [164], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Argentina<br>Departamento=%{x}<br>CC=%{y}", "legendgroup": "Pais=Argentina", "marker": {"color": "#EF553B"}, "name": "Pais=Argentina", "offsetgroup": "Pais=Argentina", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Buenos Aires", "Chubut", "Chubut", "Cordoba", "Cordoba", "Cordoba", "Cordoba", "Corrientes", "Jujuy", "Jujuy", "Jujuy", "Jujuy", "La Pampa", "La Rioja", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Mendoza", "Rio Negro", "Salta", "Salta", "San Juan", "San Luis", "Santa Cruz - Argentina", "Santa Cruz - Argentina", "Santa Fe", "Tucum\u00e1n"], "xaxis": "x", "y": [49, 4733, 9, 71, 132, 27, 128, 4, 1146, 213, 217, 96, 49, 74, 9, 43, 293, 12, 21, 2, 24, 177, 7, 7, 19, 9, 6, 173, 53, 56, 12, 8, 9, 188, 40, 12, 13, 11, 19, 33, 21], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Austria<br>Departamento=%{x}<br>CC=%{y}", "legendgroup": "Pais=Austria", "marker": {"color": "#00cc96"}, "name": "Pais=Austria", "offsetgroup": "Pais=Austria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Viena"], "xaxis": "x", "y": [45], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Belgica<br>Departamento=%{x}<br>CC=%{y}", "legendgroup": "Pais=Belgica", "marker": {"color": "#ab63fa"}, "name": "Pais=Belgica", "offsetgroup": "Pais=Belgica", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bruselas"], "xaxis": "x", "y": [124], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pais=Bolivia<br>Departamento=%{x}<br>CC=%{y}", "legendgroup": "Pais=Bolivia", "marker": {"color": "#FFA15A"}, "name": "Pais=Bolivia", "offsetgroup": "Pais=Bolivia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Beni", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Chuquisaca", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "Cochabamba", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "La Paz", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Oruro", "Pando", "Pando", "Pando", "Pando", "Pando", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Potos\u00ed", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Santa Cruz", "Tarija", "Tarija", "Tarija", "Tarija", "Tarija", "Tarija"], "xaxis": "x", "y": [24089, 8771, 1232, 811, 671, 1335, 30513, 2081, 1101, 858,  ...

# %% [markdown]
# ## Actas históricas analizadas

# %%
print("Total Actas del repositorio histórico")
len(df_actas_all)
# Out:
# Total Actas del repositorio histórico
# 2804321

# %%
df_actas_modificadas = df_actas_all [~df_actas_all.loc[:, ~df_actas_all.columns.isin(['FechaHoraArchivo', 'Id'])].duplicated(keep='first')]
print("Actas únicas con modificaciones")
len(df_actas_modificadas)
# df_actas_all.duplicated(keep='first', subset=[~df_actas_all.columns.isin(['FechaHoraArchivo', 'Id'])])
# Out:
# Actas únicas con modificaciones
# 33107

# %%
# Actas modificadas multiples veces
df_actas_modificadas_multiples_veces = df_actas_modificadas.groupby(by=['Pais', 'Departamento', 'Municipio', 'CodigoMesa']).count()['Inscritos'].reset_index()
df_actas_modificadas_multiples_veces = df_actas_modificadas_multiples_veces[df_actas_modificadas_multiples_veces['Inscritos'] > 1]
print("Actas modificadas más de una vez")
len(df_actas_modificadas_multiples_veces)
# Out:
# Actas modificadas más de una vez
# 1

# %%
print("Actas editadas")
df_actas_modificadas_multiples_veces.sort_values('Inscritos',  ascending=False).head(20)
# Out:
# Actas editadas
#          Pais    Departamento          Municipio          CodigoMesa  Inscritos
# 32811  España  Islas Baleares  Palma de Mallorca  110673137742611705          2

# %%
df_mesas_corregidas_detalle = pd.DataFrame()
for mesa in df_actas_modificadas_multiples_veces['CodigoMesa']:
  # print(mesa)
  df_mesa = df_actas_all[df_actas_all['CodigoMesa'] == mesa].copy()
  df_mesa['Duplicated'] = df_mesa.duplicated(subset=df_mesa.columns[~df_mesa.columns.isin(['Id',	'FechaHoraArchivo'])])
  df_mesas_corregidas_detalle = df_mesas_corregidas_detalle.append(df_mesa[df_mesa['Duplicated'] == False], ignore_index=True)

df_mesas_corregidas_detalle.head(50)
# Out:
#        Id    FechaHoraArchivo  ... _PartidoGanador  Duplicated
# 0    1217 2019-10-20 19:40:57  ...              CC       False
# 1  523849 2019-10-22 09:56:53  ...              CC       False
#
# [2 rows x 37 columns]

# %%
 df_mesas_corregidas_detalle.to_csv('MesasCorregidas.csv')

# %%
#@title Mesa a buscar { run: "auto", form-width: "800px" }
mesa = "100320722341108805" #@param {type:"string"}
VER = "EDICIONES UNICAS" #@param ["TODOS", "EDICIONES UNICAS", "ULTIMA ACTA"]

df_mesa = df_actas_all[df_actas_all['CodigoMesa'] == mesa].copy()
if VER == "EDICIONES UNICAS":
  df_mesa['Duplicated'] = df_mesa.duplicated(subset=df_mesa.columns[~df_mesa.columns.isin(['Id',	'FechaHoraArchivo'])])
  display(df_mesa[df_mesa['Duplicated'] == False])

elif VER == "ULTIMA ACTA":
  display(df_actas_all[(df_actas_all['FechaHoraArchivo'] == acta_final_fecha) & (df_actas_all['CodigoMesa'] == mesa)])
else:
  display(df_mesa)

# %% [markdown]
# ### Orden de Procesamiento de actas

# %%
df_llegada_actas = df_actas_all.drop_duplicates(subset=['CodigoMesa'], keep='first').copy()
df_llegada_actas.sort_values(by=["FechaHoraArchivo", "_PartidoGanador"], inplace=True)
print(len(df_llegada_actas))
df_llegada_actas.head()
# Out:
# 33044
#           Id    FechaHoraArchivo  ... _TotalAsistencia  _PartidoGanador
# 0          1 2019-10-20 19:40:57  ...               NO               CC
# 19320  19321 2019-10-20 19:40:57  ...               NO               CC
# 19319  19320 2019-10-20 19:40:57  ...               NO               CC
# 19315  19316 2019-10-20 19:40:57  ...               NO               CC
# 19314  19315 2019-10-20 19:40:57  ...               NO               CC
#
# [5 rows x 36 columns]

# %%
df_llegada_actas_resumen = df_llegada_actas.groupby(by=['FechaHoraArchivo', 'Departamento', '_PartidoGanador']).count()[['CodigoMesa']].reset_index()
df_llegada_actas_resumen.head()
# Out:
#      FechaHoraArchivo Departamento _PartidoGanador  CodigoMesa
# 0 2019-10-20 19:40:57         Acre              CC           1
# 1 2019-10-20 19:40:57    Andalucia              CC          18
# 2 2019-10-20 19:40:57    Andalucia             MAS           4
# 3 2019-10-20 19:40:57  Antofagasta              CC          29
# 4 2019-10-20 19:40:57  Antofagasta             MAS           1

# %%
configure_plotly_browser_state()
df_llegada_actas_mas_cc = df_llegada_actas_resumen[df_llegada_actas_resumen['_PartidoGanador'].isin(['MAS','CC', 'PDC'])]
fig = px.bar(df_llegada_actas_mas_cc, x="FechaHoraArchivo",  title="Orden de llegada de actas", color= "_PartidoGanador" , text="Departamento")
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="f3e28b65-e695-40b1-bb3c-b25dfb0145cf" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f3e28b65-e695-40b1-bb3c-b25dfb0145cf")) {
#                     Plotly.newPlot(
#                         'f3e28b65-e695-40b1-bb3c-b25dfb0145cf',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "_PartidoGanador=CC<br>FechaHoraArchivo=%{x}<br>Departamento=%{text}", "legendgroup": "_PartidoGanador=CC", "marker": {"color": "#636efa"}, "name": "_PartidoGanador=CC", "offsetgroup": "_PartidoGanador=CC", "orientation": "v", "showlegend": true, "text": ["Acre", "Andalucia", "Antofagasta", "Beijing", "Beni", "Berl\u00edn", "Bruselas", "Buenos Aires", "Catalu\u00f1a", "Chuquisaca", "Cochabamba", "Cusco", "Dist. Capital", "Dist. Columbia", "Distr. Federal", "Estocolmo", "Euskadi", "Ginebra", "Holanda", "Ile de France", "Inglaterra", "Islas Baleares", "Kanto", "La Paz", "Lazio", "Lima", "Lombard\u00eda", "M.Grosso do Sul", "Madrid", "Managua", "Maryland", "Metropolitana", "Montevideo", "Murcia", "M\u00e9xico D.F.", "New York", "Ontario", "Oruro", "Panam\u00e1", "Pando", "Pichincha", "Potos\u00ed", "Rodhe Island", "R\u00edo de janeiro", "San Jos\u00e9", "Santa Cruz", "Se\u00fal", "Tarapaca", "Tarija", "Valencia", "Viena", "Virginia", "Beni", "California", "Chuquisaca", "Cochabamba", "Florida", "La Paz", "Maryland", "Murcia", "New Jersey", "Oruro", "Pando", "Potos\u00ed", "Santa Cruz", "Tarija", "Virginia", "Cochabamba", "La Paz", "Santa Cruz", "Cochabamba", "La Paz", "Santa Cruz", "Cochabamba", "La Paz", "Santa Cruz"], "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T20:17:53", "2019-10-21T20:17:53", "2019-10-21T20:17:53", "2019-10-21T21:20:53", "2019-10-21T21:20:53", "2019-10-21T21:20:53", "2019-10-21T22:23:53", "2019-10-21T22:23:53", "2019-10-21T22:23:53"], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "_PartidoGanador=MAS<br>FechaHoraArchivo=%{x}<br>Departamento=%{text}", "legendgroup": "_PartidoGanador=MAS", "marker": {"color": "#EF553B"}, "name": "_PartidoGanador=MAS", "offsetgroup": "_PartidoGanador=MAS", "orientation": "v", "showlegend": true, "text": ["Andalucia", "Antofagasta", "Arica", "Atacama", "Beni", "Buenos Aires", "Chubut", "Chuquisaca", "Cochabamba", "Cordoba", "Delhi", "Distr. Federal", "El Cairo", "Jujuy", "La Habana", "La Pampa", "La Paz", "La Rioja", "Mato Grosso", "Mendoza", "Moquegua", "Murcia", "Oruro", "Pando", "Potos\u00ed", "Puno", "Rio Negro", "Salta", "San Juan", "San Luis", "Santa Cruz", "Santa Cruz - Argentina", "Santa Fe", "Sao Paulo", "Tacna", "Tarapaca", "Tarija", "Teher\u00e1n", "Tucum\u00e1n", "Virginia", "Beni", "Bu ...
#                         {"barmode": "relative", "height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.111111111

# %%
df_llegada_actas_resumen_votos = df_llegada_actas.groupby(by=['FechaHoraArchivo', '_PartidoGanador', 'Provincia']).sum()[['MAS', 'CC']].reset_index()
df_llegada_actas_resumen_votos.head()
# Out:
#      FechaHoraArchivo _PartidoGanador       Provincia     MAS      CC
# 0 2019-10-20 19:40:57              CC  Abel Iturralde     239     311
# 1 2019-10-20 19:40:57              CC           Abuna     163     257
# 2 2019-10-20 19:40:57              CC   Andres Ibañez  161205  429887
# 3 2019-10-20 19:40:57              CC  Angel Sandoval      64      69
# 4 2019-10-20 19:40:57              CC     Antofagasta     801    1700

# %%
configure_plotly_browser_state()
fig = px.bar(df_llegada_actas_resumen_votos, x="FechaHoraArchivo", y="MAS",  title="Orden de llegada de actas - Cantidad de votos MAS", color= "Provincia" )
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="1df4f6bd-9b88-4541-85ec-91ddb99623cf" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1df4f6bd-9b88-4541-85ec-91ddb99623cf")) {
#                     Plotly.newPlot(
#                         '1df4f6bd-9b88-4541-85ec-91ddb99623cf',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Abel Iturralde<br>FechaHoraArchivo=%{x}<br>MAS=%{y}", "legendgroup": "Provincia=Abel Iturralde", "marker": {"color": "#636efa"}, "name": "Provincia=Abel Iturralde", "offsetgroup": "Provincia=Abel Iturralde", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T21:20:53"], "xaxis": "x", "y": [239, 2353, 358, 155], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Abuna<br>FechaHoraArchivo=%{x}<br>MAS=%{y}", "legendgroup": "Provincia=Abuna", "marker": {"color": "#EF553B"}, "name": "Provincia=Abuna", "offsetgroup": "Provincia=Abuna", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53"], "xaxis": "x", "y": [163, 536, 68], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Andres Iba\u00f1ez<br>FechaHoraArchivo=%{x}<br>MAS=%{y}", "legendgroup": "Provincia=Andres Iba\u00f1ez", "marker": {"color": "#00cc96"}, "name": "Provincia=Andres Iba\u00f1ez", "offsetgroup": "Provincia=Andres Iba\u00f1ez", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T20:17:53", "2019-10-21T20:17:53", "2019-10-21T21:20:53", "2019-10-21T21:20:53", "2019-10-21T22:23:53", "2019-10-21T22:23:53"], "xaxis": "x", "y": [161205, 133, 128235, 0, 7395, 40, 5604, 675, 463, 1082, 954, 238, 222], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Angel Sandoval<br>FechaHoraArchivo=%{x}<br>MAS=%{y}", "legendgroup": "Provincia=Angel Sandoval", "marker": {"color": "#ab63fa"}, "name": "Provincia=Angel Sandoval", "offsetgroup": "Provincia=Angel Sandoval", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53"], "xaxis": "x", "y": [64, 1543, 54, 1150], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Antofagasta<br>FechaHoraArchivo=%{x}<br>MAS=%{y}", "legendgroup": "Provincia=Antofagasta", "marker": {"color": "#FFA15A"}, "name": "Provincia=Antofagasta", "offsetgroup": "Provincia=Antofagasta", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57"], "xaxis": "x", "y": [801, 69], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Antonio Quijarro<br>FechaHoraArchivo=%{x}<br>MAS=%{y}", "legendgroup": "Provincia=Antonio Quijarro", "marker": {"color": "#19d3f3"}, "name": "Provincia=Antonio Quijarro", "offsetgroup": "Provincia=Antonio Quijarro", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53"], "xaxis": "x", "y": [1300, 0, 5868, 785, 1231], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Arce<br>FechaHoraArchivo=%{x}<br>MAS=%{y}", "legendgroup": "Provincia=Arce", "marker": {"color": "#FF6692"}, "name": "Provincia=Arce", "offsetgroup": "Provincia=Arce", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53"], "xaxis": "x", "y": [2077, 10929, 1339, 2680], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Arlington<br>FechaHoraArchivo=%{x} ...

# %%
configure_plotly_browser_state()
fig = px.bar(df_llegada_actas_resumen_votos, x="FechaHoraArchivo", y="CC",  title="Orden de llegada de actas - Cantidad de votos CC", color= "Provincia" )
fig.show()
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="223dcb7d-2380-4916-a8df-5be33687c933" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("223dcb7d-2380-4916-a8df-5be33687c933")) {
#                     Plotly.newPlot(
#                         '223dcb7d-2380-4916-a8df-5be33687c933',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Abel Iturralde<br>FechaHoraArchivo=%{x}<br>CC=%{y}", "legendgroup": "Provincia=Abel Iturralde", "marker": {"color": "#636efa"}, "name": "Provincia=Abel Iturralde", "offsetgroup": "Provincia=Abel Iturralde", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T21:20:53"], "xaxis": "x", "y": [311, 1161, 162, 87], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Abuna<br>FechaHoraArchivo=%{x}<br>CC=%{y}", "legendgroup": "Provincia=Abuna", "marker": {"color": "#EF553B"}, "name": "Provincia=Abuna", "offsetgroup": "Provincia=Abuna", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53"], "xaxis": "x", "y": [257, 197, 9], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Andres Iba\u00f1ez<br>FechaHoraArchivo=%{x}<br>CC=%{y}", "legendgroup": "Provincia=Andres Iba\u00f1ez", "marker": {"color": "#00cc96"}, "name": "Provincia=Andres Iba\u00f1ez", "offsetgroup": "Provincia=Andres Iba\u00f1ez", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T19:14:53", "2019-10-21T20:17:53", "2019-10-21T20:17:53", "2019-10-21T21:20:53", "2019-10-21T21:20:53", "2019-10-21T22:23:53", "2019-10-21T22:23:53"], "xaxis": "x", "y": [429887, 143, 76631, 73, 20995, 43, 3416, 1868, 294, 2919, 624, 544, 65], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Angel Sandoval<br>FechaHoraArchivo=%{x}<br>CC=%{y}", "legendgroup": "Provincia=Angel Sandoval", "marker": {"color": "#ab63fa"}, "name": "Provincia=Angel Sandoval", "offsetgroup": "Provincia=Angel Sandoval", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53"], "xaxis": "x", "y": [69, 708, 94, 580], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Antofagasta<br>FechaHoraArchivo=%{x}<br>CC=%{y}", "legendgroup": "Provincia=Antofagasta", "marker": {"color": "#FFA15A"}, "name": "Provincia=Antofagasta", "offsetgroup": "Provincia=Antofagasta", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57"], "xaxis": "x", "y": [1700, 64], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Antonio Quijarro<br>FechaHoraArchivo=%{x}<br>CC=%{y}", "legendgroup": "Provincia=Antonio Quijarro", "marker": {"color": "#19d3f3"}, "name": "Provincia=Antonio Quijarro", "offsetgroup": "Provincia=Antonio Quijarro", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53"], "xaxis": "x", "y": [2141, 6, 2894, 1386, 407], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Arce<br>FechaHoraArchivo=%{x}<br>CC=%{y}", "legendgroup": "Provincia=Arce", "marker": {"color": "#FF6692"}, "name": "Provincia=Arce", "offsetgroup": "Provincia=Arce", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-10-20T19:40:57", "2019-10-20T19:40:57", "2019-10-21T19:14:53", "2019-10-21T19:14:53"], "xaxis": "x", "y": [2695, 4348, 1654, 1768], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Provincia=Arlington<br>FechaHoraArchivo=%{x}<br>CC=%{y ...
